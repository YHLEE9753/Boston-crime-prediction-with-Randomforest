# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f_oneway
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression,Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
crime=pd.read_csv('C:/Users/kwon/Desktop/crime_final2.csv')

# %%
catvar=['District2']
for c in catvar:
    dummy = pd.get_dummies(crime[c], prefix=c, drop_first=True)
    crime = pd.concat((crime,dummy),axis=1)

# %%
import statsmodels.api as sm
X = crime.drop(catvar+['final_count'],axis=1)
X.columns
# Out:
# Index(['Unnamed: 0', 'SHOOTING_Y', 'UCR_PART_Part One', 'Low Temp (F)',
#        'High Humidity (%)', 'Low Humidity (%)', 'Avg Visibility (mi)',
#        'Low Visibility (mi)', 'Avg Wind (mph)', 'High Wind Gust (mph)',
#        'Snowfall (in)', 'Precip (in)', 'CrimeGunsRecovered',
#        'GunsRecoveredSafeguard', 'BuybackGunsRecovered',
#        'Shooting_Type_V2_Non-Fatal', 'Victim_Gender_Male',
#        'Victim_Race_Black or African American', 'Victim_Race_White',
#        'Victim_Ethnicity_NIBRS_Not Hispanic or Latinx', 'Multi_Victim_t',
#        'police_count', 'landmark_count', 'District2_Charlestown',
#        'District2_Dorchester', 'District2_East Boston', 'District2_Hyde Park',
#        'District2_Jamaica Plain', 'District2_Mattapan', 'District2_Roxbury',
#        'District2_South Boston', 'District2_West Roxbury'],
#       dtype='object')

# %%
y=crime['final_count']
X=sm.add_constant(X)

model=sm.OLS(y,X.astype(float))

result = model.fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            final_count   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     2913.
# Date:                Wed, 24 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:18:18   Log-Likelihood:            -2.0461e+05
# No. Observations:               70116   AIC:                         4.093e+05
# Df Residuals:                   70085   BIC:                         4.096e+05
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# ...

# %%
X = crime.drop(catvar+['final_count','High Wind Gust (mph)','Victim_Gender_Male','Victim_Ethnicity_NIBRS_Not Hispanic or Latinx','District2_Charlestown','District2_Jamaica Plain'],axis=1)
y=crime['final_count']
X=sm.add_constant(X)

model=sm.OLS(y,X.astype(float))

result = model.fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            final_count   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     3361.
# Date:                Wed, 24 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:33:30   Log-Likelihood:            -2.0461e+05
# No. Observations:               70116   AIC:                         4.093e+05
# Df Residuals:                   70089   BIC:                         4.095e+05
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# ...

# %%
X = crime.drop(catvar+['final_count','High Wind Gust (mph)','Victim_Gender_Male','Victim_Ethnicity_NIBRS_Not Hispanic or Latinx','District2_Charlestown','District2_Jamaica Plain','GunsRecoveredSafeguard','landmark_count'],axis=1)
y=crime['final_count']
X=sm.add_constant(X)

model=sm.OLS(y,X.astype(float))

result = model.fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            final_count   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     3641.
# Date:                Wed, 24 Nov 2021   Prob (F-statistic):               0.00
# Time:                        14:34:33   Log-Likelihood:            -2.0461e+05
# No. Observations:               70116   AIC:                         4.093e+05
# Df Residuals:                   70091   BIC:                         4.095e+05
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split

trainX, testX, trainY, testY = train_test_split(X,y, 
                                                    test_size=0.2, 
                                                    shuffle=True,
                                                    random_state=1004)



print('trainX shape:', trainX.shape)
print('testX shape:', testX.shape)
print('trainY shape:', trainY.shape)
print('testY shape:', testY.shape)
# Out:
# trainX shape: (56092, 26)
# testX shape: (14024, 26)
# trainY shape: (56092,)
# testY shape: (14024,)

# %%
# Model
reg1=LinearRegression()
reg2=Ridge(alpha=1)
reg3=Lasso(alpha=1)

#fit
reg1.fit(trainX,trainY)
reg2.fit(trainX,trainY)
reg3.fit(trainX,trainY)

#Linear Regression
print('Linear Regression(train):',reg1.score(trainX,trainY))
print('Linear Regression(test):',reg1.score(testX,testY))

#Ridge Regression
print('Ridge Regression(train):',reg2.score(trainX,trainY))
print('Ridge Regression(test):',reg2.score(testX,testY))


#Lasso Regression
print('Lasso Regression(train):',reg3.score(trainX,trainY))
print('Lasso Regression(test):',reg3.score(testX,testY))
# Out:
# Linear Regression(train): 0.5538572355532208
# Linear Regression(val): 0.5587197531953498
# Ridge Regression(train): 0.5538572234890227
# Ridge Regression(val): 0.5587160920175003
# Lasso Regression(train): 0.3655201296900755
# Lasso Regression(val): 0.3665686399787418
